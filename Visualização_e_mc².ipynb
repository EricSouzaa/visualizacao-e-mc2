# %% [markdown]
# # 💡 Visualização de E = mc² com Matplotlib
#
# Este mini projeto visualiza a famosa equação de Einstein, `E = mc²`, usando dois gráficos:
#
# - Um gráfico em **escala linear** (normal)
# - Um gráfico com **escala logarítmica no eixo Y**
#
# A ideia é mostrar como a energia cresce com a massa e como a escala log ajuda a visualizar melhor esse crescimento.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
m = np.linspace(0, 10, 11)  # massa de 0 a 10 g
c = 3 * (10**8)             # velocidade da luz em m/s
e = m * (c**2)              # E = mc²

# %% [markdown]
# ## 📈 Criação dos gráficos
#
# Aqui vamos visualizar dois gráficos lado a lado:
#
# - À esquerda: escala normal
# - À direita: escala logarítmica no eixo Y

# %%
fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

# Gráfico com escala normal
axes[0].plot(m, e, color='blue')
axes[0].set_xlabel('Mass (g)')
axes[0].set_ylabel('Energy (J)')
axes[0].set_title('E = mc² (Escala Normal)')
axes[0].grid(True)

# Gráfico com escala logarítmica no eixo Y
axes[1].plot(m, e, color='red')
axes[1].set_xlabel('Mass (g)')
axes[1].set_ylabel('Energy (J)')
axes[1].set_title('E = mc² (Escala Logarítmica)')
axes[1].set_yscale('log')
axes[1].grid(True, which='both', axis='y')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ Conclusão
#
# - A equação `E = mc²` mostra que **pequenas massas geram enormes quantidades de energia**, por conta do valor absurdo de `c²`.
# - A escala logarítmica ajuda a visualizar o crescimento exponencial da energia à medida que a massa aumenta.
#
# Esse tipo de visualização é útil tanto para ensino quanto para comunicar conceitos de física de forma visual.
#
# ---
# 📌 Projeto feito com Python, NumPy e Matplotlib.
